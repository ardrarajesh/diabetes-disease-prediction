# %% [markdown]
# # DIABETES PATIENT PREDICTION USING DIFFERENT ML ALGORITHMS

# %%
#importing neccessary libaries
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#importing dataset
df=pd.read_csv(r"C:\Users\ardrakr\OneDrive\Desktop\DUK2ND\capstone project\diabetes2.csv")

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.shape
# Out:
# (768, 9)

# %%
#The first 5 rows
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#The last 5 rows
df.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#Statistical information of data
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
#Checking on null values
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
plt.figure(figsize=[20,12])
ax1 = plt.subplot(3,2,1)
ax2 = plt.subplot(3,2,2)
ax3 = plt.subplot(3,2,3)
ax4 = plt.subplot(3,2,4)
ax5 = plt.subplot(3,2,5)
sns.histplot(data=df, x='Glucose', kde=True, ax=ax1)
sns.histplot(data=df, x='SkinThickness', kde=True, ax=ax2)
sns.histplot(data=df, x='BloodPressure', kde=True, ax=ax3)
sns.histplot(data=df, x='Insulin', kde=True, ax=ax4)
sns.histplot(data=df, x='BMI', kde=True, ax=ax5)
plt.show()

# %%
df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df['BloodPressure'].fillna(df['BloodPressure'].mean(), inplace = True)
df['Glucose'].fillna(df['Glucose'].median(), inplace = True)
df['BMI'].fillna(df['BMI'].median(), inplace = True)
df['SkinThickness'].fillna(df['SkinThickness'].median(), inplace = True)
df['Insulin'].fillna(df['Insulin'].median(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#box plot for outlier detection
sns.set(style="whitegrid")
df.boxplot(figsize=(15,6))
# Out:
# <AxesSubplot:>

# %%
#box plot
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(4,2)})
sns.boxplot(x=df['Insulin'])
plt.show()
sns.boxplot(x=df['BloodPressure'])
plt.show()
sns.boxplot(x=df['DiabetesPedigreeFunction'])
plt.show()

# %%
#calculation of interquartile range

Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1

print("---Q1--- \n",Q1)
print("\n---Q3--- \n",Q3)
print("\n---IQR---\n",IQR)
# Out:
# ---Q1---
#  Pregnancies                   1.00000
# Glucose                      99.75000
# BloodPressure                64.00000
# SkinThickness                25.00000
# Insulin                     121.50000
# BMI                          27.50000
# DiabetesPedigreeFunction      0.24375
# Age                          24.00000
# Outcome                       0.00000
# Name: 0.25, dtype: float64
#
# ---Q3---
#  Pregnancies                   6.00000
# Glucose                     140.25000
# BloodPressure                80.00000
# SkinThickness                32.00000
# Insulin                     127.25000
# BMI                          36.60000
# DiabetesPedigreeFunction      0.62625
# Age                          41.00000
# Outcome                       1.00000
# Name: 0.75, dtype: float64
#
# ---IQR---
#  Pregnancies                  5.0000
# Glucose                     40.5000
# BloodPressure               16.0000
# SkinThickness                7.0000
# Insulin                      5.7500
# BMI                          9.1000
# DiabetesPedigreeFunction     0.3825
# Age                         17.0000
# Outcome                      1.0000
# dtype: float64

# %%
#outlier removal
df= df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (375, 9)

# %%
#Scatter matrix after removing outlier
sns.set(style="ticks")
sns.pairplot(df, hue="Outcome")
plt.show()

# %%
plt.title("Count plot representing diabetic and non diabetic patients ")
sns.countplot(df["Outcome"])
plt.show()
# Out:
# C:\Users\ardrakr\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Outcome'].value_counts()
# Out:
# 0    237
# 1    138
# Name: Outcome, dtype: int64

# %%
labels = [ 'Non-Diabetic','Diabetic']
explode=(0.1,0)
plt.pie(x=df['Outcome'].value_counts(),explode=explode,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1eee3495580>,
#   <matplotlib.patches.Wedge at 0x1eee3495a60>],
#  [Text(-0.483487823217766, 1.0982893629641264, 'Non-Diabetic'),
#   Text(0.44319726554311595, -1.006765207888664, 'Diabetic')])

# %%
df.hist(figsize = (20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Pregnancies'}>,
#         <AxesSubplot:title={'center':'Glucose'}>,
#         <AxesSubplot:title={'center':'BloodPressure'}>],
#        [<AxesSubplot:title={'center':'SkinThickness'}>,
#         <AxesSubplot:title={'center':'Insulin'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'DiabetesPedigreeFunction'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Outcome'}>]], dtype=object)

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True,cmap ='Blues')
# Out:
# <AxesSubplot:>

# %%
#Splitting the dataset
X=df.drop(labels="Outcome",axis=1)
y=df["Outcome"]

# %%
#Splitting the dataset for testing and training 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y,test_size=0.3,random_state=42)

# %%
# show train data and shapes

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (262, 8)
# (113, 8)
# (262,)
# (113,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ### LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

#  create model instance 
log= LogisticRegression()

#  Model Fitting
log = log.fit(X_train, y_train)

log_pred = log.predict(X_test)

# Model Accuracy
log_accuracy=accuracy_score(y_test,log_pred)
print("accuracy score:",log_accuracy)

# confusion matrix
print("confusion matrix:\n")
confusion_matrix(y_test, log_pred)
print(confusion_matrix(y_test, log_pred))


#classification report for logistic regression model
print("\nclassification report:\n")
print(classification_report(y_test,log_pred ))
# Out:
# accuracy score: 0.7610619469026548
# confusion matrix:
#
# [[61 10]
#  [17 25]]
#
# classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82        71
#            1       0.71      0.60      0.65        42
#
#     accuracy                           0.76       113
#    macro avg       0.75      0.73      0.73       113
# weighted avg       0.76      0.76      0.76       113

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Plotting a accuracy graph
X_axis = list(range(1, 31))
accuracy = pd.Series()

for i in X_axis:
    knn= KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    pred= knn.predict(X_test)
    accuracy= accuracy.append(pd.Series(metrics.accuracy_score(pred,y_test)))
plt.figure(figsize=(9,9))
plt.plot(X_axis, accuracy)  
plt.xticks(range(1,31))
plt.title("Finding best value for n_estimators")
plt.xlabel("n_estimators")
plt.ylabel("Accuracy")
plt.grid()
plt.show()    
print('Highest accuracy: ',accuracy.values.max())
# Out:
# <ipython-input-47-7d9aed5389ad>:3: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   accuracy = pd.Series()
# Highest accuracy:  0.7787610619469026

# %%
#  create model instance 
knn= KNeighborsClassifier(n_neighbors=22)

#  Model Fitting
knn=knn.fit(X_train, y_train)

knn_pred = knn.predict(X_test)

# Model Accuracy
knn_accuracy=accuracy_score(y_test,knn_pred)
print("accuracy score:",knn_accuracy)

# confusion matrix
print("confusion matrix:\n")
confusion_matrix(y_test, knn_pred)
print(confusion_matrix(y_test,knn_pred))

#classification report for knn model
print("\nclassification report:\n")
print(classification_report(y_test,knn_pred ))
# Out:
# accuracy score: 0.7787610619469026
# confusion matrix:
#
# [[64  7]
#  [18 24]]
#
# classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84        71
#            1       0.77      0.57      0.66        42
#
#     accuracy                           0.78       113
#    macro avg       0.78      0.74      0.75       113
# weighted avg       0.78      0.78      0.77       113

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

#  create model instance 
svm_linear=SVC(kernel="linear")

#  Model Fitting
svm_linear.fit(X_train,y_train)

svm_pred = svm_linear.predict(X_test)

# Model Accuracy
svm_accuracy=accuracy_score(y_test,svm_pred)
print("accuracy score:",svm_accuracy)

# confusion matrix
print("confusion matrix:\n")
confusion_matrix(y_test,svm_pred)
print(confusion_matrix(y_test, svm_pred))

#classification report for svm model
print("\nclassification report:\n")
print(classification_report(y_test,svm_pred ))
# Out:
# accuracy score: 0.7876106194690266
# confusion matrix:
#
# [[64  7]
#  [17 25]]
#
# classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84        71
#            1       0.78      0.60      0.68        42
#
#     accuracy                           0.79       113
#    macro avg       0.79      0.75      0.76       113
# weighted avg       0.79      0.79      0.78       113

# %% [markdown]
# ### RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Finding out the right number of estimators
accuracy=[]
x_axis=list(range(1,1000,100))
for i in range(1,1000,100):
    random = RandomForestClassifier(n_estimators = i, random_state = 0)
    random.fit(X_train,y_train)
    rf_pred =random.predict(X_test)
    accuracy.append(accuracy_score(y_test,rf_pred))

plt.figure(figsize=(9,9))
plt.title("Finding best value for n_estimators")
plt.xlabel("n_estimators")
plt.ylabel("Accuracy")
plt.xticks(x_axis)
plt.grid()
plt.plot(x_axis, accuracy)    
print('Highest accuracy: ',max(accuracy))
# Out:
# Highest accuracy:  0.7433628318584071

# %%
#  create model instance 
random=RandomForestClassifier(n_estimators = 601)

#  Model Fitting
random.fit(X_train,y_train)

rf_pred =random.predict(X_test)

# Model Accuracy
rf_accuracy=accuracy_score(y_test,rf_pred)
print("accuracy score:",rf_accuracy)

# confusion matrix
print("confusion matrix:\n")
confusion_matrix(y_test, rf_pred )
print(confusion_matrix(y_test, rf_pred ))

#classification report for random forest model
print("\nclassification report:\n")
print(classification_report(y_test,rf_pred ))
# Out:
# accuracy score: 0.7610619469026548
# confusion matrix:
#
# [[62  9]
#  [18 24]]
#
# classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82        71
#            1       0.73      0.57      0.64        42
#
#     accuracy                           0.76       113
#    macro avg       0.75      0.72      0.73       113
# weighted avg       0.76      0.76      0.75       113

# %% [markdown]
# ### NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB

#  create model instance 
nb=GaussianNB()

#  Model Fitting
nb.fit(X_train,y_train)

nb_pred =nb.predict(X_test)

# Model Accuracy
nb_accuracy=accuracy_score(y_test,nb_pred)
print("accuracy score:",nb_accuracy)

# confusion matrix
print("confusion matrix:\n")
confusion_matrix(y_test,nb_pred )
print(confusion_matrix(y_test, nb_pred))

#classification report for naive bayes model
print("\nclassification report:\n")
print(classification_report(y_test,nb_pred ))
# Out:
# accuracy score: 0.7522123893805309
# confusion matrix:
#
# [[57 14]
#  [14 28]]
#
# classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        71
#            1       0.67      0.67      0.67        42
#
#     accuracy                           0.75       113
#    macro avg       0.73      0.73      0.73       113
# weighted avg       0.75      0.75      0.75       113

# %% [markdown]
# ###  DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier

#  create model instance 
dt=DecisionTreeClassifier(criterion="entropy")

#  Model Fitting
dt.fit(X_train,y_train)

dt_pred =dt.predict(X_test)

#accuraccy
dt_accuracy=accuracy_score(y_test,dt_pred)
print("accuracy score:",dt_accuracy)

# confusion matrix
print("confusion matrix:")
confusion_matrix(y_test,dt_pred )
print(confusion_matrix(y_test, dt_pred ))


#classification report for decision tree model
print("\nclassification report:\n")
print(classification_report(y_test,dt_pred ))
# Out:
# accuracy score: 0.6814159292035398
# confusion matrix:
# [[51 20]
#  [16 26]]
#
# classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74        71
#            1       0.57      0.62      0.59        42
#
#     accuracy                           0.68       113
#    macro avg       0.66      0.67      0.67       113
# weighted avg       0.69      0.68      0.68       113

# %%
from sklearn import tree
tree.plot_tree(dt)
# Out:
# [Text(93.84545454545454, 105.85894736842106, 'X[1] <= -0.284\nentropy = 0.948\nsamples = 262\nvalue = [166, 96]'),
#  Text(30.436363636363637, 100.13684210526316, 'X[7] <= -0.357\nentropy = 0.619\nsamples = 117\nvalue = [99, 18]'),
#  Text(13.527272727272727, 94.41473684210527, 'X[5] <= 2.111\nentropy = 0.124\nsamples = 59\nvalue = [58, 1]'),
#  Text(6.763636363636364, 88.69263157894737, 'entropy = 0.0\nsamples = 58\nvalue = [58, 0]'),
#  Text(20.29090909090909, 88.69263157894737, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(47.345454545454544, 94.41473684210527, 'X[1] <= -0.887\nentropy = 0.873\nsamples = 58\nvalue = [41, 17]'),
#  Text(33.81818181818182, 88.69263157894737, 'X[3] <= 0.392\nentropy = 0.414\nsamples = 24\nvalue = [22, 2]'),
#  Text(27.054545454545455, 82.97052631578947, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(40.58181818181818, 82.97052631578947, 'X[7] <= 0.752\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(33.81818181818182, 77.24842105263158, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(47.345454545454544, 77.24842105263158, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(60.872727272727275, 88.69263157894737, 'X[5] <= -0.945\nentropy = 0.99\nsamples = 34\nvalue = [19, 15]'),
#  Text(54.10909090909091, 82.97052631578947, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(67.63636363636364, 82.97052631578947, 'X[7] <= -0.272\nentropy = 0.999\nsamples = 29\nvalue = [14, 15]'),
#  Text(60.872727272727275, 77.24842105263158, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(74.4, 77.24842105263158, 'X[6] <= 2.052\nentropy = 0.99\nsamples = 25\nvalue = [14, 11]'),
#  Text(67.63636363636364, 71.52631578947368, 'X[6] <= -0.604\nentropy = 0.918\nsamples = 21\nvalue = [14, 7]'),
#  Text(43.96363636363636, 65.80421052631579, 'X[2] <= 0.533\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(37.2, 60.08210526315789, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(50.72727272727273, 60.08210526315789, 'X[2] <= 1.218\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(43.96363636363636, 54.36, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(57.49090909090909, 54.36, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.30909090909091, 65.80421052631579, 'X[6] <= 0.455\nentropy = 0.996\nsamples = 13\nvalue = [7, 6]'),
#  Text(84.54545454545455, 60.08210526315789, 'X[2] <= 0.729\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]'),
#  Text(71.01818181818182, 54.36, 'X[2] <= -1.423\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(64.25454545454545, 48.63789473684211, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(77.78181818181818, 48.63789473684211, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(98.07272727272728, 54.36, 'X[2] <= 2.295\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(91.30909090909091, 48.63789473684211, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(104.83636363636364, 48.63789473684211, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(98.07272727272728, 60.08210526315789, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(81.16363636363636, 71.52631578947368, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(157.25454545454545, 100.13684210526316, 'X[5] <= 1.873\nentropy = 0.996\nsamples = 145\nvalue = [67, 78]'),
#  Text(150.4909090909091, 94.41473684210527, 'X[5] <= -0.699\nentropy = 1.0\nsamples = 133\nvalue = [67, 66]'),
#  Text(104.83636363636364, 88.69263157894737, 'X[0] <= -0.568\nentropy = 0.738\nsamples = 24\nvalue = [19, 5]'),
#  Text(98.07272727272728, 82.97052631578947, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(111.6, 82.97052631578947, 'X[1] <= 0.318\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]'),
#  Text(104.83636363636364, 77.24842105263158, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(118.36363636363636, 77.24842105263158, 'X[5] <= -0.839\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]'),
#  Text(111.6, 71.52631578947368, 'X[5] <= -1.535\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(104.83636363636364, 65.80421052631579, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(118.36363636363636, 65.80421052631579, 'X[4] <= 2.385\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(111.6, 60.08210526315789, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(125.12727272727273, 60.08210526315789, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(125.12727272727273, 71.52631578947368, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(196.14545454545456, 88.69263157894737, 'X[6] <= 1.441\nentropy = 0.99\nsamples = 109\nvalue = [48, 61]'),
#  Text(182.61818181818182, 82.97052631578947, 'X[1] <= 2.161\nentropy = 1.0\nsamples = 94\nvalue = [46, 48]'),
#  Text(175.85454545454544, 77.24842105263158, 'X[7] <= 2.33\nentropy = 0.999\nsamples = 89\nvalue = [46, 43]'),
#  Text(169.0909090909091, 71.52631578947368, 'X[7] <= 0.581\nentropy = 1.0\nsamples = 84\nvalue = [41, 43]'),
#  Text(152.1818181818182, 65.80421052631579, 'X[2] <= 0.925\nentropy = 0.982\nsamples = 64\nvalue = [37, 27]'),
#  Text(138.65454545454546, 60.08210526315789, 'X[1] <= -0.213\nentropy = 1.0\nsamples = 53\nvalue = [27, 26]'),
#  Text(131.8909090909091, 54.36, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(145.4181818181818, 54.36, 'X[1] <= -0.178\nentropy = 0.995\nsamples = 50\nvalue = [27, 23]'),
#  Text(138.65454545454546, 48.63789473684211, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(152.1818181818182, 48.63789473684211, 'X[3] <= -1.612\nentropy = 1.0\nsamples = 47\nvalue = [24, 23]'),
#  Text(145.4181818181818, 42.915789473684214, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(158.94545454545454, 42.915789473684214, 'X[6] <= -0.634\nentropy = 0.997\nsamples = 45\nvalue = [24, 21]'),
#  Text(134.42727272727274, 37.193684210526314, 'X[0] <= 1.363\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]'),
#  Text(127.66363636363637, 31.471578947368428, 'X[7] <= -0.997\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(120.9, 25.74947368421053, 'X[5] <= 0.349\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(114.13636363636364, 20.02736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(127.66363636363637, 20.02736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(134.42727272727274, 25.74947368421053, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(141.1909090909091, 31.471578947368428, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(183.46363636363637, 37.193684210526314, 'X[7] <= 0.411\nentropy = 0.971\nsamples = 35\nvalue = [21, 14]'),
#  Text(176.7, 31.471578947368428, 'X[0] <= 0.62\nentropy = 0.993\nsamples = 31\nvalue = [17, 14]'),
#  Text(158.1, 25.74947368421053, 'X[2] <= -0.445\nentropy = 0.943\nsamples = 25\nvalue = [16, 9]'),
#  Text(141.1909090909091, 20.02736842105263, 'X[3] <= 0.814\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(134.42727272727274, 14.305263157894743, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(147.95454545454547, 14.305263157894743, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(175.0090909090909, 20.02736842105263, 'X[0] <= -0.271\nentropy = 0.998\nsamples = 17\nvalue = [9, 8]'),
#  Text(161.48181818181817, 14.305263157894743, 'X[1] <= -0.019\nentropy = 0.764\nsamples = 9\nvalue = [7, 2]'),
#  Text(154.71818181818182, 8.583157894736843, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(168.24545454545455, 8.583157894736843, 'X[1] <= 0.903\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(161.48181818181817, 2.861052631578943, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(175.0090909090909, 2.861052631578943, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(188.53636363636363, 14.305263157894743, 'X[1] <= 0.921\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]'),
#  Text(181.77272727272728, 8.583157894736843, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(195.3, 8.583157894736843, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(195.3, 25.74947368421053, 'X[0] <= 1.808\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(188.53636363636363, 20.02736842105263, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(202.06363636363636, 20.02736842105263, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(190.22727272727272, 31.471578947368428, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(165.70909090909092, 60.08210526315789, 'X[0] <= 0.917\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(158.94545454545454, 54.36, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(172.47272727272727, 54.36, 'X[5] <= 0.21\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(165.70909090909092, 48.63789473684211, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(179.23636363636365, 48.63789473684211, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(186.0, 65.80421052631579, 'X[2] <= 0.533\nentropy = 0.722\nsamples = 20\nvalue = [4, 16]'),
#  Text(179.23636363636365, 60.08210526315789, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(192.76363636363635, 60.08210526315789, 'X[1] <= 0.371\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]'),
#  Text(186.0, 54.36, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(199.52727272727273, 54.36, 'X[2] <= 1.512\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]'),
#  Text(192.76363636363635, 48.63789473684211, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(206.29090909090908, 48.63789473684211, 'X[6] <= -0.018\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(199.52727272727273, 42.915789473684214, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(213.05454545454546, 42.915789473684214, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(182.61818181818182, 71.52631578947368, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(189.38181818181818, 77.24842105263158, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(209.6727272727273, 82.97052631578947, 'X[7] <= -0.869\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]'),
#  Text(202.9090909090909, 77.24842105263158, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(216.43636363636364, 77.24842105263158, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(164.01818181818183, 94.41473684210527, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]')]

# %% [markdown]
# ### GRADIENT BOOSTING CLASSIFIER

# %%
#  create model instance
boost=GradientBoostingClassifier(n_estimators=50,learning_rate=0.2)

#  Model Fitting
boost.fit(X_train,y_train)

gb_pred=boost.predict(X_test)

#accuraccy
gb_accuracy=accuracy_score(y_test,gb_pred)
print("accuracy score:",gb_accuracy)

# confusion matrix
print("confusion matrix:")
confusion_matrix(y_test,gb_pred )
print(confusion_matrix(y_test, gb_pred ))

#classification report for gradient boosting model
print("\nclassification report:\n")
print(classification_report(y_test,gb_pred ))
# Out:
# accuracy score: 0.7345132743362832
# confusion matrix:
# [[57 14]
#  [16 26]]
#
# classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79        71
#            1       0.65      0.62      0.63        42
#
#     accuracy                           0.73       113
#    macro avg       0.72      0.71      0.71       113
# weighted avg       0.73      0.73      0.73       113

# %% [markdown]
# ### ADABOOST

# %%
#  create model instance
adaboost = AdaBoostClassifier(n_estimators=100, random_state=0)

#  Model Fitting
adaboost.fit(X_train,y_train)

ada_pred=adaboost.predict(X_test)

#accuraccy
ada_accuracy=accuracy_score(y_test,ada_pred)
print("accuracy score:",ada_accuracy)

# confusion matrix
print("confusion matrix:")
confusion_matrix(y_test,ada_pred )
print(confusion_matrix(y_test, ada_pred ))

#classification report for adaboost model
print("\nclassification report:\n")
print(classification_report(y_test,ada_pred ))
# Out:
# accuracy score: 0.7168141592920354
# confusion matrix:
# [[57 14]
#  [18 24]]
#
# classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78        71
#            1       0.63      0.57      0.60        42
#
#     accuracy                           0.72       113
#    macro avg       0.70      0.69      0.69       113
# weighted avg       0.71      0.72      0.71       113

# %% [markdown]
# ### MODEL COMAPARISON

# %%
# Accuracy on test data
print("Logistic Regression: " + str(log_accuracy * 100))
print("K Nearest neighbors: " + str(knn_accuracy * 100))
print("Support Vector Classifier: " + str(svm_accuracy * 100))
print("Naive Bayes: " + str(nb_accuracy* 100))
print("Decision tree: " + str(dt_accuracy * 100))
print("Random Forest: " + str(rf_accuracy * 100))
print("Gradient Boosting:"+str(gb_accuracy*100))
print("AdaBoost:"+str(ada_accuracy*100))
# Out:
# Logistic Regression: 76.10619469026548
# K Nearest neighbors: 77.87610619469027
# Support Vector Classifier: 78.76106194690266
# Naive Bayes: 75.22123893805309
# Decision tree: 68.14159292035397
# Random Forest: 76.10619469026548
# Gradient Boosting:73.45132743362832
# AdaBoost:71.68141592920354

# %%
#Bar graph for accuracy comparison
ax=plt.figure(figsize=(9,4))
accuracy=[log_accuracy,knn_accuracy,svm_accuracy,nb_accuracy,dt_accuracy ,rf_accuracy,gb_accuracy,ada_accuracy]
plt.bar(['Logistic Regression','KNN','SVM','NB','DT','RF','Boosting','adaboost'],accuracy,label='Accuracy')
plt.ylabel('Accuracy Score')
plt.xlabel('Algortihms')
plt.title("algorithm vs accuracy")
plt.show()
